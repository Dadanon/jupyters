# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# %%
x = np.random.random(100).reshape((20, 5)) * 20
numbers.shape
# Out:
# (20, 5)

# %%
y = np.empty(20, dtype='<U10')
for i in range(0, 20, 2):
    y[i] = 'First'
    y[i+1] = 'Second'
y.reshape((20, 1))
# Out:
# array([['First'],
#        ['Second'],
#        ['First'],
#        ['Second'],
#        ['First'],
#        ['Second'],
#        ['First'],
#        ['Second'],
#        ['First'],
#        ['Second'],
#        ['First'],
#        ['Second'],
#        ['First'],
#        ['Second'],
#        ['First'],
#        ['Second'],
#        ['First'],
#        ['Second'],
#        ['First'],
#        ['Second']], dtype='<U10')

# %%
y.shape
# Out:
# (20,)

# %%
x = np.column_stack((x, y))

# %%
x.shape
# Out:
# (20, 6)

# %%
data = pd.DataFrame(
    data = x,
    columns=['f1', 'f2', 'f3', 'f4', 'f5', 'Class']
)

# %%
# data = data.astype({'f1': 'float64', 'f2': 'float64', 'f3': 'float64', 'f4': 'float64', 'f5': 'float64'})
# data.astype('float64')
'''for nr, c in enumerate(data.columns):
    if c != 'Class':
        data.astype({c: 'float64'})'''

# %%
data = data.astype({'f1': 'float64', 'f2': 'float64', 'f3': 'float64', 'f4': 'float64', 'f5': 'float64'})

# %%
data.dtypes
# Out:
# f1       float64
# f2       float64
# f3       float64
# f4       float64
# f5       float64
# Class     object
# dtype: object

# %%
fig, axes = plt.subplots(nrows = 3, ncols = 2, figsize = (20, 40))
for nr, c in enumerate(data.columns):
    if c!= 'Class':
        sns.boxplot(data = data, x = 'Class', y = c, ax = axes[nr // 2, nr % 2], palette = 'winter')
        axes[nr // 2, nr % 2].set_title('BoxPlot of ' + c + ' for pumpkin classes')
plt.subplots_adjust(hspace = 0.5, wspace = 0.5)
